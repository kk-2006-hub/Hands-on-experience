# %% [markdown]
# <a href="https://colab.research.google.com/github/kk-2006-hub/Hands-on-experience/blob/main/LAST_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sin=SentimentIntensityAnalyzer()

# %%
sin.polarity_scores('watching this movie is waste of time')
# Out:
# {'neg': 0.318, 'neu': 0.682, 'pos': 0.0, 'compound': -0.4215}
